# %% [markdown]
# <a href="https://colab.research.google.com/github/alecveda-wq/PytLab/blob/main/Copy_of_Week_4_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Homework
#
# (Be sure to copy to drive)
#
# I have put a lot different things in front of you during this course. Thanks for indulging me as I try to both impress you with what Python can do, and make the code readable.
#
# For homework this week, we are going to go real light.

# %% [markdown]
# **H1** To bring what you learned in the week 4 warmup to life I'd like you to:
#
# - Create a GitHub repository
# - Save your week 1 homework in that GitHub Repository in the way described in the warmup
# - Share the URL to your repository in the cell below

# %%
repository_url = "https://github.com/alecveda-wq/PytLab/blob/main/Copy_of_Week_1_Homework.ipynb"

# %% [markdown]
# **H1 Continued**
#
# You don't have to keep that repository forever, feel free to delete it after this class is done.

# %% [markdown]
# **H2** Starting in the week 3 homework we began an analysis on a collection of PDF files that you created. The week 4 workalong asked you to create PDF summaries for those same files.
#
# I'd just like to see what your final analysis looks like. Run the cells below to load up those csv files and to display them to the screen.

# %%
from google.colab import drive
import pandas as pd

#Because the summaries are big, I'm going to set no maximum column size in pandas so I see
#the complete summary
pd.set_option('display.max_colwidth', None)

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # PDF Summaries

# %%
pdf_summaries = pd.read_csv("/content/gdrive/MyDrive/LibraryJuicePython/adv_week4_pdf_summaries.csv")
pdf_summaries
# Out:
#                  Filename  \
# 0    Ballerina review.pdf
# 1   Ballerina review2.pdf
# 2   Ballerina Review3.pdf
# 3  Ballerina review 4.pdf
# 4  Ballerina review 5.pdf
# 5  Ballerina review 6.pdf
#
#                                                                                                                                                                                                                                                                                                                                                                     Summary
# 0                                                                                       Lionsgate stretches the John Wick franchise just a little too thin with the half bloody, half boring                 Ballerina. Director Len Wiseman lets the lines just play out with no emphasizing style accentuating the threats, shocking plot reveals, and action one-liners.
# 1                                                                                               Ballerina checks every box of a John Wick film! It just gives you what you want from these movies. The revenge-driven plot is serviceable but basic, with flat characters who lack compelling motivations. It's the action - not the narrative - that keeps the film alive.
# 2  Ballerina is shockingly really good. The scenes with John Wick were amazing, but every scene that didn't include him was equally as good. I liked Eve's character more than I expected to, and even though he wasn't in the movie that much, I did enjoy the scenes with Norman Reedus as Daniel Pine. This might just be the most action-packed movie of the franchise.
# 3                                                                                                               Get ready for plenty of fighting and gunfight scenes when you take your seat. Nearly three-quarters of the film consists of this type of scene. The grenade scenes were over-the-top and even absurd, but the flamethrower scene was the most entertaining.
# 4                         “Ballerina” is a halfway decent action movie that will suffer because it lives in the massive shadow of “John Wick, one of the best modern franchises. The early action scenes in director Len Wiseman’s vision will be dispiriting for fans of the franchise. The last third of the film is basically one extended, truly goofy action sequence.
# 5                                                “Ballerina” is a stylish, entertaining, and surprisingly self-contained action thriller in its own right. Ana de Armas plays Eve with steely focus and simmering rage. It’s a classic revenge story dressed up in the “John Wick” universe. The first 45 minutes of action tee up the film to break up the breakneck pace.

# %% [markdown]
# #PDF Details

# %%
pdf_data = pd.read_csv("/content/gdrive/MyDrive/LibraryJuicePython/adv_week3_homework.csv")
pdf_data
# Out:
#                      filename  polarity  subjectivity  keyword_1  \
# 0  Ballerina review 4.pdf.txt  0.184722      0.539616  john wick
# 1    Ballerina review.pdf.txt -0.037564      0.527467  ballerina
# 2   Ballerina review2.pdf.txt  0.139507      0.453085  ballerina
# 3  Ballerina review 5.pdf.txt  0.117547      0.445085  ballerina
# 4   Ballerina Review3.pdf.txt  0.283135      0.495913  john wick
# 5  Ballerina review 6.pdf.txt  0.143011      0.523128  ballerina
#
#         keyword_2 keyword_3
# 0  main character    fights
# 1             ’ s     armas
# 2       john wick      wick
# 3             ’ s      wick
# 4       ballerina    review
# 5       john wick       ’ s

# %% [markdown]
# ## All Done!
#
# Congrats you have finished Advanced Python for Librarians!
#
# Don't forget to click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work. Please also save this notebook as a PDF and upload it the Library Juice Academy LMS.
