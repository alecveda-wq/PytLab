# %% [markdown]
# <a href="https://colab.research.google.com/github/alecveda-wq/PytLab/blob/main/Copy_of_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
# @title URL of JSON File for complete CollectionBuilder Metadata {"run":"auto","display-mode":"form"}

json_cb_url = "https://geniza.github.io/paleographicalglossary/assets/data/subjects.json" # @param {"type":"string","placeholder":"https://geniza.github.io/paleographicalglossary/assets/data/metadata.json"}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
subjects_cb_data = total_cb_data['subjects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(subjects_cb_data))
print(json.dumps(subjects_cb_data[random_entry],indent=2))
# Out:
# {
#   "subject": "unit of volume",
#   "count": 2,
#   "link": "https://geniza.github.io/paleographicalglossary/browse.html#unit%20of%20volume"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://geniza.github.io/paleographicalglossary/assets/data/facets.json" # @param {"type":"string","placeholder":"https://geniza.github.io/paleographicalglossary/assets/data/facets.json"}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'subjects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "abbreviation": 1,
#         "austrian": 1,
#         "ayyubid": 8,
#         "byzantine": 7,
#         "coin": 73,
#         "currency quality": 4,
#         "currently unattested": 12,
#         "dutch": 2,
#         "early modern": 22,
#         "fatimid": 6,
#         "florentine": 1,
#         "fractions": 1,
#         "french": 1,
#         "hungary": 1,
#         "indian ocean": 6,
#         "judaeo-spanish influence": 7,
#         "karaite": 1,
#         "malabar coast": 5,
#         "mamluk": 15,
#         "material culture": 1,
#         "medieval": 30,
#         "medieval and early modern": 38,
#         "medieval and early modern, spanish": 1,
#         "mint standard": 2,
#         "modern": 1,
#         "nagid": 1,
#         "norman": 1,
#         "ottoman": 31,
#         "regnal variant": 6,
#         "safavid": 1,
#         "spanish": 1,
#         "sulayhid": 1,
#         "unit": 2,
#         "unit of account": 6,
#         "unit of area": 1,
#         "unit of measurement": 1,
#         "unit of volume": 2,
#         "unit of weight": 12,
#         "venetian": 5,
#         "yemen": 5
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 104
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - facet 1 "subject"
# - facet 2 "creator"
# - facet 3 "format"

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is "subject" it is used 43 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['subjects'])
cb_normalized
# Out:
#                                subject  count  \
# 0                         abbreviation      1
# 1                             austrian      1
# 2                              ayyubid      8
# 3                            byzantine      7
# 4                                 coin     73
# 5                     currency quality      4
# 6                 currently unattested     12
# 7                                dutch      2
# 8                         early modern     22
# 9                              fatimid      6
# 10                          florentine      1
# 11                           fractions      1
# 12                              french      1
# 13                             hungary      1
# 14                        indian ocean      6
# 15            judaeo-spanish influence      7
# 16                             karaite      1
# 17                       malabar coast      5
# 18                              mamluk     15
# 19                    material culture      1
# 20                            medieval     30
# 21           medieval and early modern     38
# 22  medieval and early modern, spanish      1
# 23                       mint standard      2
# 24                              modern      1
# 25                               nagid      1
# 26                              norman      1
# 27                             ottoman     31
# 28                      regnal variant      6
# 29                             safavid      1
# 30                             spanish      1
# 31                            sulayhid      1
# 32                                unit      2
# 33                     unit of account      6
# 34                        unit of area      1
# 35                 unit of measurement      1
# 36                      unit of volume      2
# 37                      unit of weight     12
# 38                            venetian      5
# 39                               yemen      5
#
#                                                  link
# 0   https://geniza.github.io/paleographicalglossar...
# 1   https://geniza.github.io/paleographicalglossar...
# 2   https://geniza.github.io/paleographicalglossar...
# 3   https://geniza.github.io/paleographicalglossar...
# 4   https://geniza.github.io/paleographicalglossar...
# 5   https://geniza.github.io/paleographicalglossar...
# 6   https://geniza.github.io/paleographicalglossar...
# 7   https://geniza.github.io/paleographicalglossar...
# 8   https://geniza.github.io/paleographicalglossar...
# 9   https://geniza.github.io/paleographicalglossar...
# 10  https://geniza.github.io/paleographicalglossar...
# 11  https://geniza.github.io/paleographicalglossar...
# 12  https://geniza.github.io/paleographicalglossar...
# 13  https://geniza.github.io/paleographicalglossar...
# 14  https://geniza.github.io/paleographicalglossar...
# 15  https://geniza.github.io/paleographicalglossar...
# 16  https://geniza.github.io/paleographicalglossar...
# 17  https://geniza.github.io/paleographicalglossar...
# 18  https://geniza.github.io/paleographicalglossar...
# 19  https://geniza.github.io/paleographicalglossar...
# 20  https://geniza.github.io/paleographicalglossar...
# 21  https://geniza.github.io/paleographicalglossar...
# 22  https://geniza.github.io/paleographicalglossar...
# 23  https://geniza.github.io/paleographicalglossar...
# 24  https://geniza.github.io/paleographicalglossar...
# 25  https://geniza.github.io/paleographicalglossar...
# 26  https://geniza.github.io/paleographicalglossar...
# 27  https://geniza.github.io/paleographicalglossar...
# 28  https://geniza.github.io/paleographicalglossar...
# 29  https://geniza.github.io/paleographicalglossar...
# 30  https://geniza.github.io/paleographicalglossar...
# 31  https://geniza.github.io/paleographicalglossar...
# 32  https://geniza.github.io/paleographicalglossar...
# 33  https://geniza.github.io/paleographicalglossar...
# 34  https://geniza.github.io/paleographicalglossar...
# 35  https://geniza.github.io/paleographicalglossar...
# 36  https://geniza.github.io/paleographicalglossar...
# 37  https://geniza.github.io/paleographicalglossar...
# 38  https://geniza.github.io/paleographicalglossar...
# 39  https://geniza.github.io/paleographicalglossar...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#              subject  count                                               link
# 1           austrian      1  https://geniza.github.io/paleographicalglossar...
# 28    regnal variant      6  https://geniza.github.io/paleographicalglossar...
# 5   currency quality      4  https://geniza.github.io/paleographicalglossar...
# 25             nagid      1  https://geniza.github.io/paleographicalglossar...
# 17     malabar coast      5  https://geniza.github.io/paleographicalglossar...
# 38          venetian      5  https://geniza.github.io/paleographicalglossar...
# 29           safavid      1  https://geniza.github.io/paleographicalglossar...
# 11         fractions      1  https://geniza.github.io/paleographicalglossar...
# 2            ayyubid      8  https://geniza.github.io/paleographicalglossar...
# 14      indian ocean      6  https://geniza.github.io/paleographicalglossar...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized[cb_normalized[""] == ""].count()

# %%
#H6

cb_normalized["subject"].value_counts()
# Out:
# subject
# abbreviation                          1
# austrian                              1
# ayyubid                               1
# byzantine                             1
# coin                                  1
# currency quality                      1
# currently unattested                  1
# dutch                                 1
# early modern                          1
# fatimid                               1
# florentine                            1
# fractions                             1
# french                                1
# hungary                               1
# indian ocean                          1
# judaeo-spanish influence              1
# karaite                               1
# malabar coast                         1
# mamluk                                1
# material culture                      1
# medieval                              1
# medieval and early modern             1
# medieval and early modern, spanish    1
# mint standard                         1
# modern                                1
# nagid                                 1
# norman                                1
# ottoman                               1
# regnal variant                        1
# safavid                               1
# spanish                               1
# sulayhid                              1
# unit                                  1
# unit of account                       1
# unit of area                          1
# unit of measurement                   1
# unit of volume                        1
# unit of weight                        1
# venetian                              1
# yemen                                 1
# Name: count, dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
